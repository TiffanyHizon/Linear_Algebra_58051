# %% [markdown]
# <a href="https://colab.research.google.com/github/TiffanyHizon/Linear_Algebra_58051/blob/main/Laboratory%20Activity%205/LinAlg_58051_Hizon_Multidimensional_Vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TASK 1**
#
# Given a  R=1  vector in a 2-dimensional plane and visualize it using the cells below. In the first markdown cell below, write your vector using LaTeX. You should represent it as a system of linear equations. In your methodology discuss the different functions that you have used, the equation of your vectors, and the flowchart for declaring and displaying your vector. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the vector visualization code you made.

# %% [markdown]
# $$A = 3x + 4y$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([3, 4])

plt.xlim(0, 10)
plt.ylim(0, 10)

plt.quiver(0, 0, A[0], A[1], angles='xy', scale_units='xy', scale=1, color="goldenrod", label='A')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # **TASK 2**
#
# Given a  R=2  vector in a 3-dimensional plane and visualize it using the cells below. In the first markdown cell below, write your vector using LaTeX. You should represent it as a system of linear equations. In your methodology discuss the different functions that you have used, the equation of your vectors, and the flowchart for declaring and displaying your vector. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the vector visualization code you made.

# %% [markdown]
# $$
# A = \left\{
#     \begin{array}\\
#         3x + 6y + 8z \\
#         x + 2y + 4z\\
#         2x+ y + 10z
#     \end{array}
# \right. $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([
            [3, 6, 8],
            [1, 2, 4], 
            [2, 1, 10]  
             ])

figure = plt.figure()
axis = figure.gca(projection='3d')

axis.set_xlim(0, 15)
axis.set_ylim(0, 15)
axis.set_zlim(0, 15)

plt.quiver(0, 0, 0, A[0, 0], A[0, 1], A[0, 2], color='darkslategray')
plt.quiver(0, 0, 0, A[1, 0], A[1, 1], A[1, 2], color="salmon")
plt.quiver(0, 0, 0, A[2, 0], A[2, 1], A[2, 2], color="green")

plt.show()
